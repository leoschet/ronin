# %% [markdown]
# # Process YouTube subtitles

# %% [markdown]
# ## Dependencies

# %%
import json
import os

import pandas as pd
import polars as pl

import tidder.polars as tpl
from tidder.data import Captions, Video

# %% [markdown]
# ## Constants

# %%
DATA_PATH = "/Users/leonardoschettini/Documents/personal/tidder/data/"

DATA_PATH
# Out:
# '/Users/leonardoschettini/Documents/personal/tidder/data/'

# %%
SAMPLE_DATA_PATH = os.path.join(
    DATA_PATH,
    "Dan Koe/channel/20231105 - The Greatest Skill Of The 21st Century (The Top 1% Exploit This)",
)

SAMPLE_DATA_PATH
# Out:
# '/Users/leonardoschettini/Documents/personal/tidder/data/Dan Koe/channel/20231105 - The Greatest Skill Of The 21st Century (The Top 1% Exploit This)'

# %%
AUTO_SUBTITLE_FILE_NAME = "auto-subtitle.en.vtt"
EN_US_SUBTITLE_FILE_NAME = "subtitle.en-US.vtt"
VIDEO_INFO_FILE_NAME = "video.info.json"

# %%
SAMPLE_AUTO_SUBTITLE_FILE = os.path.join(SAMPLE_DATA_PATH, AUTO_SUBTITLE_FILE_NAME)
SAMPLE_EN_US_SUBTITLE_FILE = os.path.join(SAMPLE_DATA_PATH, EN_US_SUBTITLE_FILE_NAME)
SAMPLE_VIDEO_INFO_FILE = os.path.join(SAMPLE_DATA_PATH, VIDEO_INFO_FILE_NAME)

# %%
# Read text file content
with open(SAMPLE_AUTO_SUBTITLE_FILE, "r") as f:
    print(f.read())
# Out:
# WEBVTT
# Kind: captions
# Language: en
#
# 00:00:00.120 --> 00:00:02.389 align:start position:0%
#
# the<00:00:00.240><c> greatest</c><00:00:00.599><c> skill</c><00:00:00.960><c> of</c><00:00:01.079><c> the</c><00:00:01.240><c> 21st</c><00:00:01.760><c> century</c>
#
# 00:00:02.389 --> 00:00:02.399 align:start position:0%
# the greatest skill of the 21st century
#
#
# 00:00:02.399 --> 00:00:04.749 align:start position:0%
# the greatest skill of the 21st century
# is<00:00:02.600><c> not</c><00:00:03.000><c> email</c><00:00:03.360><c> marketing</c><00:00:03.919><c> it</c><00:00:04.040><c> is</c><00:00:04.160><c> not</c><00:00:04.400><c> graphic</c>
#
# 00:00:04.749 --> 00:00:04.759 align:start position:0%
# is not email marketing it is not graphic
#
#
# 00:00:04.759 --> 00:00:06.909 align:start position:0%
# is not email marketing it is not graphic
# design<00:00:05.319><c> it</c><00:00:05.440><c> is</c><00:00:05.560><c> not</c><00:00:05.759><c> web</c><00:00:06.000><c> design</c><00:00:06.480><c> it</c><00:00:06.600><c> is</c><00:00:06.720><c> not</c>
#
# 00:00:06.909 --> 00:00:06.919 align:start position:0%
# design it is not web design it is not
#
#
# 00:00:06.919 --> 00:00:08.549 align:start position:0%
# design it is not web design it is not
# artificial<00:00:07.439><c> intelligence</c><00:00:08.160><c> it</c><00:00:08.240><c> is</c><00:00:08.360><c> not</c>
#
# 00:00:08.549 --> 00:00:08.559 align:start position:0%
# artificial intelligence it is not
#
#
# 00:00:08.559 --> 00:00:11.070 align:start position:0%
# artificial intelligence it is not
# personal<00:00:08.880><c> branding</c><00:00:09.519><c> it</c><00:00:09.599><c> is</c><00:00:09.800><c> not</c><00:00:10.280><c> videography</c>
#
# 00:00:11.070 --> 00:00:11.080 align:start position:0%
# personal branding it is not videography
#
#
# 00:00:11.080 --> 00:00:14.430 align:start position:0%
# personal branding it is not videography
# or<00:00:11.320><c> photography</c><00:00:12.240><c> or</c><00:00:12.960><c> video</c><00:00:13.360><c> editing</c><00:00:13.880><c> or</c><00:00:14.080><c> photo</c>
#
# 00:00:14.430 --> 00:00:14.440 align:start position:0%
# or photography or video editing or photo
#
#
# 00:00:14.440 --> 00:00:16.870 align:start position:0%
# or photography or video editing or photo
# editing<00:00:15.040><c> it</c><00:00:15.200><c> is</c><00:00:15.440><c> the</c><00:00:15.639><c> base</c><00:00:16.000><c> layer</c><00:00:16.400><c> of</c><00:00:16.600><c> all</c><00:00:16.720><c> of</c>
#
# 00:00:16.870 --> 00:00:16.880 align:start position:0%
# editing it is the base layer of all of
#
#
# 00:00:16.880 --> 00:00:19.029 align:start position:0%
# editing it is the base layer of all of
# the<00:00:17.039><c> skills</c><00:00:17.359><c> that</c><00:00:17.520><c> I</c><00:00:17.680><c> just</c><00:00:17.840><c> mentioned</c><00:00:18.520><c> so</c><00:00:18.880><c> the</c>
#
# 00:00:19.029 --> 00:00:19.039 align:start position:0%
# the skills that I just mentioned so the
#
#
# 00:00:19.039 --> 00:00:22.029 align:start position:0%
# the skills that I just mentioned so the
# greatest<00:00:19.359><c> skill</c><00:00:19.680><c> of</c><00:00:19.800><c> the</c><00:00:19.960><c> 21st</c><00:00:20.519><c> century</c><00:00:21.359><c> is</c>
#
# 00:00:22.029 --> 00:00:22.039 align:start position:0%
# greatest skill of the 21st century is
#
#
# 00:00:22.039 --> 00:00:24.150 align:start position:0%
# greatest skill of the 21st century is
# persuasive<00:00:22.880><c> communication</c><00:00:23.760><c> but</c><00:00:24.000><c> that</c>
#
# 00:00:24.150 --> 00:00:24.160 align:start position:0%
# persuasive communication but that
#
#
# 00:00:24.160 --> 00:00:25.790 align:start position:0%
# persuasive communication but that
# doesn't<00:00:24.400><c> make</c><00:00:24.680><c> sense</c><00:00:25.080><c> when</c><00:00:25.199><c> I</c><00:00:25.359><c> just</c><00:00:25.519><c> say</c>
#
# 00:00:25.790 --> 00:00:25.800 align:start position:0%
# doesn't make sense when I just say
#
#
# 00:00:25.800 --> 00:00:27.790 align:start position:0%
# doesn't make sense when I just say
# persuasive<00:00:26.359><c> communication</c><00:00:27.240><c> and</c><00:00:27.400><c> nobody</c>
#
# 00:00:27.790 --> 00:00:27.800 align:start position:0%
# persuasive communication and nobody
#
#
# 00:00:27.800 --> 00:00:29.589 align:start position:0%
# persuasive communication and nobody
# really<00:00:28.039><c> tells</c><00:00:28.279><c> you</c><00:00:28.439><c> to</c><00:00:28.599><c> learn</c><00:00:29.000><c> that</c><00:00:29.240><c> specific</c>
#
# 00:00:29.589 --> 00:00:29.599 align:start position:0%
# really tells you to learn that specific
#
#
# 00:00:29.599 --> 00:00:31.150 align:start position:0%
# really tells you to learn that specific
# skill<00:00:30.000><c> instead</c><00:00:30.279><c> they</c><00:00:30.400><c> tell</c><00:00:30.560><c> you</c><00:00:30.679><c> to</c><00:00:30.840><c> learn</c>
#
# 00:00:31.150 --> 00:00:31.160 align:start position:0%
# skill instead they tell you to learn
#
#
# 00:00:31.160 --> 00:00:33.150 align:start position:0%
# skill instead they tell you to learn
# things<00:00:31.400><c> like</c><00:00:31.640><c> copywriting</c><00:00:32.320><c> or</c><00:00:32.520><c> marketing</c><00:00:33.000><c> or</c>
#
# 00:00:33.150 --> 00:00:33.160 align:start position:0%
# things like copywriting or marketing or
#
#
# 00:00:33.160 --> 00:00:35.229 align:start position:0%
# things like copywriting or marketing or
# sales<00:00:33.760><c> they're</c><00:00:33.960><c> all</c><00:00:34.160><c> somewhat</c><00:00:34.559><c> synonymous</c>
#
# 00:00:35.229 --> 00:00:35.239 align:start position:0%
# sales they're all somewhat synonymous
#
#
# 00:00:35.239 --> 00:00:37.510 align:start position:0%
# sales they're all somewhat synonymous
# but<00:00:35.440><c> I</c><00:00:35.520><c> want</c><00:00:35.879><c> you</c><00:00:36.040><c> to</c><00:00:36.760><c> understand</c><00:00:37.320><c> the</c>
#
# 00:00:37.510 --> 00:00:37.520 align:start position:0%
# but I want you to understand the
#
#
# 00:00:37.520 --> 00:00:39.910 align:start position:0%
# but I want you to understand the
# framework<00:00:38.280><c> the</c><00:00:38.480><c> structure</c><00:00:39.120><c> of</c><00:00:39.360><c> how</c><00:00:39.600><c> all</c><00:00:39.719><c> of</c>
#
# 00:00:39.910 --> 00:00:39.920 align:start position:0%
# framework the structure of how all of
#
#
# 00:00:39.920 --> 00:00:41.709 align:start position:0%
# framework the structure of how all of
# those<00:00:40.160><c> things</c><00:00:40.440><c> work</c><00:00:40.840><c> and</c><00:00:41.000><c> how</c><00:00:41.160><c> they</c><00:00:41.320><c> impact</c>
#
# 00:00:41.709 --> 00:00:41.719 align:start position:0%
# those things work and how they impact
#
#
# 00:00:41.719 --> 00:00:43.549 align:start position:0%
# those things work and how they impact
# human<00:00:42.000><c> psychology</c><00:00:42.800><c> because</c><00:00:43.200><c> why</c><00:00:43.320><c> are</c><00:00:43.440><c> we</c>
#
# 00:00:43.549 --> 00:00:43.559 align:start position:0%
# human psychology because why are we
#
#
# 00:00:43.559 --> 00:00:45.229 align:start position:0%
# human psychology because why are we
# learning<00:00:43.960><c> skills</c><00:00:44.280><c> in</c><00:00:44.399><c> the</c><00:00:44.559><c> first</c><00:00:44.840><c> place</c><00:00:45.079><c> it's</c>
#
# 00:00:45.229 --> 00:00:45.239 align:start position:0%
# learning skills in the first place it's
#
#
# 00:00:45.239 --> 00:00:48.549 align:start position:0%
# learning skills in the first place it's
# to<00:00:45.960><c> give</c><00:00:46.239><c> value</c><00:00:46.920><c> and</c><00:00:47.480><c> therefore</c><00:00:48.079><c> acquire</c>
#
# 00:00:48.549 --> 00:00:48.559 align:start position:0%
# to give value and therefore acquire
#
#
# 00:00:48.559 --> 00:00:51.590 align:start position:0%
# to give value and therefore acquire
# value<00:00:49.160><c> so</c><00:00:49.960><c> that</c><00:00:50.360><c> exchange</c><00:00:50.960><c> between</c><00:00:51.320><c> two</c>
#
# 00:00:51.590 --> 00:00:51.600 align:start position:0%
# value so that exchange between two
#
#
# 00:00:51.600 --> 00:00:53.750 align:start position:0%
# value so that exchange between two
# individuals<00:00:52.399><c> means</c><00:00:52.760><c> that</c><00:00:52.879><c> you</c><00:00:53.079><c> have</c><00:00:53.199><c> to</c>
#
# 00:00:53.750 --> 00:00:53.760 align:start position:0%
# individuals means that you have to
#
#
# 00:00:53.760 --> 00:00:55.830 align:start position:0%
# individuals means that you have to
# understand<00:00:54.039><c> the</c><00:00:54.160><c> other</c><00:00:54.359><c> individual</c><00:00:55.120><c> if</c><00:00:55.399><c> value</c>
#
# 00:00:55.830 --> 00:00:55.840 align:start position:0%
# understand the other individual if value
#
#
# 00:00:55.840 --> 00:00:58.150 align:start position:0%
# understand the other individual if value
# is<00:00:56.160><c> perception</c><00:00:57.079><c> and</c><00:00:57.280><c> other</c><00:00:57.520><c> people</c><00:00:57.840><c> can't</c>
#
# 00:00:58.150 --> 00:00:58.160 align:start position:0%
# is perception and other people can't
#
#
# 00:00:58.160 --> 00:00:59.950 align:start position:0%
# is perception and other people can't
# perceive<00:00:58.600><c> what</c><00:00:58.719><c> you</c><00:00:58.879><c> have</c><00:00:59.039><c> to</c><00:00:59.239><c> offer</c><00:00:59.600><c> as</c>
#
# 00:00:59.950 --> 00:00:59.960 align:start position:0%
# perceive what you have to offer as
#
#
# 00:00:59.960 --> 00:01:02.910 align:start position:0%
# perceive what you have to offer as
# valuable<00:01:00.800><c> then</c><00:01:01.199><c> you're</c><00:01:01.480><c> not</c><00:01:02.120><c> going</c><00:01:02.359><c> to</c><00:01:02.680><c> get</c>
#
# 00:01:02.910 --> 00:01:02.920 align:start position:0%
# valuable then you're not going to get
#
#
# 00:01:02.920 --> 00:01:04.710 align:start position:0%
# valuable then you're not going to get
# the<00:01:03.160><c> value</c><00:01:03.519><c> that</c><00:01:03.640><c> you</c><00:01:03.760><c> want</c><00:01:03.920><c> to</c><00:01:04.159><c> receive</c><00:01:04.600><c> and</c>
#
# 00:01:04.710 --> 00:01:04.720 align:start position:0%
# the value that you want to receive and
#
#
# 00:01:04.720 --> 00:01:07.230 align:start position:0%
# the value that you want to receive and
# in<00:01:04.920><c> most</c><00:01:05.199><c> cases</c><00:01:06.080><c> that</c><00:01:06.200><c> is</c><00:01:06.360><c> going</c><00:01:06.520><c> to</c><00:01:06.640><c> be</c><00:01:06.760><c> money</c>
#
# 00:01:07.230 --> 00:01:07.240 align:start position:0%
# in most cases that is going to be money
#
#
# 00:01:07.240 --> 00:01:09.910 align:start position:0%
# in most cases that is going to be money
# so<00:01:07.439><c> if</c><00:01:07.520><c> you</c><00:01:07.600><c> do</c><00:01:07.840><c> not</c><00:01:08.080><c> know</c><00:01:08.360><c> how</c><00:01:08.520><c> to</c><00:01:08.799><c> persuade</c><00:01:09.439><c> or</c>
#
# 00:01:09.910 --> 00:01:09.920 align:start position:0%
# so if you do not know how to persuade or
#
#
# 00:01:09.920 --> 00:01:11.429 align:start position:0%
# so if you do not know how to persuade or
# understand<00:01:10.080><c> the</c><00:01:10.240><c> psychology</c><00:01:10.880><c> of</c><00:01:11.000><c> the</c><00:01:11.159><c> person</c>
#
# 00:01:11.429 --> 00:01:11.439 align:start position:0%
# understand the psychology of the person
#
#
# 00:01:11.439 --> 00:01:13.429 align:start position:0%
# understand the psychology of the person
# you're<00:01:11.640><c> trying</c><00:01:11.880><c> to</c><00:01:12.119><c> exchange</c><00:01:12.560><c> value</c><00:01:12.960><c> with</c>
#
# 00:01:13.429 --> 00:01:13.439 align:start position:0%
# you're trying to exchange value with
#
#
# 00:01:13.439 --> 00:01:15.710 align:start position:0%
# you're trying to exchange value with
# whether<00:01:13.680><c> it's</c><00:01:13.799><c> in</c><00:01:13.920><c> a</c><00:01:14.159><c> relationship</c><00:01:15.159><c> or</c><00:01:15.560><c> just</c>
#
# 00:01:15.710 --> 00:01:15.720 align:start position:0%
# whether it's in a relationship or just
#
#
# 00:01:15.720 --> 00:01:17.270 align:start position:0%
# whether it's in a relationship or just
# in<00:01:16.000><c> business</c><00:01:16.439><c> whether</c><00:01:16.640><c> you're</c><00:01:16.880><c> approaching</c>
#
# 00:01:17.270 --> 00:01:17.280 align:start position:0%
# in business whether you're approaching
#
#
# 00:01:17.280 --> 00:01:19.190 align:start position:0%
# in business whether you're approaching
# someone<00:01:17.520><c> at</c><00:01:17.640><c> a</c><00:01:17.799><c> bar</c><00:01:18.400><c> or</c><00:01:18.600><c> you're</c><00:01:18.840><c> approaching</c>
#
# 00:01:19.190 --> 00:01:19.200 align:start position:0%
# someone at a bar or you're approaching
#
#
# 00:01:19.200 --> 00:01:21.230 align:start position:0%
# someone at a bar or you're approaching
# someone<00:01:19.439><c> in</c><00:01:19.600><c> the</c><00:01:19.720><c> DMS</c><00:01:20.240><c> it's</c><00:01:20.479><c> all</c><00:01:20.759><c> the</c><00:01:20.920><c> same</c>
#
# 00:01:21.230 --> 00:01:21.240 align:start position:0%
# someone in the DMS it's all the same
#
#
# 00:01:21.240 --> 00:01:23.910 align:start position:0%
# someone in the DMS it's all the same
# thing<00:01:21.799><c> you</c><00:01:22.040><c> have</c><00:01:22.280><c> cultivated</c><00:01:22.840><c> value</c><00:01:23.079><c> to</c><00:01:23.280><c> offer</c>
#
# 00:01:23.910 --> 00:01:23.920 align:start position:0%
# thing you have cultivated value to offer
#
#
# 00:01:23.920 --> 00:01:26.230 align:start position:0%
# thing you have cultivated value to offer
# you<00:01:24.079><c> need</c><00:01:24.280><c> to</c><00:01:24.640><c> persuade</c><00:01:25.200><c> the</c><00:01:25.400><c> other</c><00:01:25.720><c> person</c><00:01:26.040><c> to</c>
#
# 00:01:26.230 --> 00:01:26.240 align:start position:0%
# you need to persuade the other person to
#
#
# 00:01:26.240 --> 00:01:28.270 align:start position:0%
# you need to persuade the other person to
# see<00:01:26.560><c> that</c><00:01:26.799><c> value</c><00:01:27.360><c> so</c><00:01:27.520><c> that</c><00:01:27.720><c> they</c><00:01:27.840><c> can</c><00:01:28.000><c> give</c><00:01:28.119><c> you</c>
#
# 00:01:28.270 --> 00:01:28.280 align:start position:0%
# see that value so that they can give you
#
#
# 00:01:28.280 --> 00:01:30.270 align:start position:0%
# see that value so that they can give you
# the<00:01:28.400><c> value</c><00:01:28.720><c> that</c><00:01:28.799><c> you</c><00:01:28.920><c> want</c><00:01:29.119><c> in</c><00:01:29.439><c> return</c><00:01:30.000><c> and</c><00:01:30.159><c> in</c>
#
# 00:01:30.270 --> 00:01:30.280 align:start position:0%
# the value that you want in return and in
#
#
# 00:01:30.280 --> 00:01:32.749 align:start position:0%
# the value that you want in return and in
# the<00:01:30.439><c> context</c><00:01:30.840><c> that</c><00:01:31.040><c> we</c><00:01:31.240><c> talk</c><00:01:31.479><c> about</c><00:01:31.680><c> a</c><00:01:31.840><c> lot</c><00:01:32.159><c> for</c>
#
# 00:01:32.749 --> 00:01:32.759 align:start position:0%
# the context that we talk about a lot for
#
#
# 00:01:32.759 --> 00:01:34.469 align:start position:0%
# the context that we talk about a lot for
# like<00:01:32.960><c> online</c><00:01:33.360><c> writing</c><00:01:33.799><c> or</c><00:01:34.000><c> becoming</c><00:01:34.320><c> a</c>
#
# 00:01:34.469 --> 00:01:34.479 align:start position:0%
# like online writing or becoming a
#
#
# 00:01:34.479 --> 00:01:36.030 align:start position:0%
# like online writing or becoming a
# Creator<00:01:34.920><c> or</c><00:01:35.079><c> starting</c><00:01:35.360><c> a</c><00:01:35.479><c> onep</c><00:01:35.680><c> person</c>
#
# 00:01:36.030 --> 00:01:36.040 align:start position:0%
# Creator or starting a onep person
#
#
# 00:01:36.040 --> 00:01:38.109 align:start position:0%
# Creator or starting a onep person
# business<00:01:36.759><c> persuasive</c><00:01:37.280><c> communication</c><00:01:37.880><c> comes</c>
#
# 00:01:38.109 --> 00:01:38.119 align:start position:0%
# business persuasive communication comes
#
#
# 00:01:38.119 --> 00:01:40.190 align:start position:0%
# business persuasive communication comes
# into<00:01:38.360><c> play</c><00:01:38.759><c> in</c><00:01:39.000><c> everything</c><00:01:39.640><c> if</c><00:01:39.880><c> with</c><00:01:40.040><c> your</c>
#
# 00:01:40.190 --> 00:01:40.200 align:start position:0%
# into play in everything if with your
#
#
# 00:01:40.200 --> 00:01:42.389 align:start position:0%
# into play in everything if with your
# writing<00:01:40.960><c> it</c><00:01:41.200><c> has</c><00:01:41.360><c> to</c><00:01:41.479><c> be</c><00:01:41.640><c> persuasive</c><00:01:42.200><c> if</c><00:01:42.280><c> you</c>
#
# 00:01:42.389 --> 00:01:42.399 align:start position:0%
# writing it has to be persuasive if you
#
#
# 00:01:42.399 --> 00:01:43.590 align:start position:0%
# writing it has to be persuasive if you
# want<00:01:42.560><c> it</c><00:01:42.640><c> to</c><00:01:42.759><c> be</c><00:01:42.840><c> shared</c><00:01:43.200><c> if</c><00:01:43.280><c> it's</c><00:01:43.439><c> not</c>
#
# 00:01:43.590 --> 00:01:43.600 align:start position:0%
# want it to be shared if it's not
#
#
# 00:01:43.600 --> 00:01:45.429 align:start position:0%
# want it to be shared if it's not
# persuasive<00:01:44.119><c> it's</c><00:01:44.280><c> not</c><00:01:44.399><c> going</c><00:01:44.520><c> to</c><00:01:44.680><c> resonate</c><00:01:45.280><c> or</c>
#
# 00:01:45.429 --> 00:01:45.439 align:start position:0%
# persuasive it's not going to resonate or
#
#
# 00:01:45.439 --> 00:01:47.789 align:start position:0%
# persuasive it's not going to resonate or
# be<00:01:45.560><c> seen</c><00:01:46.000><c> as</c><00:01:46.240><c> valuable</c><00:01:46.600><c> to</c><00:01:46.799><c> other</c><00:01:47.040><c> people</c><00:01:47.640><c> so</c>
#
# 00:01:47.789 --> 00:01:47.799 align:start position:0%
# be seen as valuable to other people so
#
#
# 00:01:47.799 --> 00:01:50.109 align:start position:0%
# be seen as valuable to other people so
# that<00:01:48.040><c> they</c><00:01:48.280><c> exchange</c><00:01:48.719><c> the</c><00:01:48.920><c> value</c><00:01:49.360><c> of</c><00:01:49.960><c> them</c>
#
# 00:01:50.109 --> 00:01:50.119 align:start position:0%
# that they exchange the value of them
#
#
# 00:01:50.119 --> 00:01:52.069 align:start position:0%
# that they exchange the value of them
# sharing<00:01:50.600><c> the</c><00:01:50.759><c> content</c><00:01:51.320><c> that's</c><00:01:51.520><c> what</c><00:01:51.640><c> you</c><00:01:51.799><c> want</c>
#
# 00:01:52.069 --> 00:01:52.079 align:start position:0%
# sharing the content that's what you want
#
#
# 00:01:52.079 --> 00:01:53.749 align:start position:0%
# sharing the content that's what you want
# from<00:01:52.280><c> them</c><00:01:52.439><c> when</c><00:01:52.560><c> you're</c><00:01:52.799><c> posting</c><00:01:53.240><c> content</c>
#
# 00:01:53.749 --> 00:01:53.759 align:start position:0%
# from them when you're posting content
#
#
# 00:01:53.759 --> 00:01:55.830 align:start position:0%
# from them when you're posting content
# right<00:01:54.119><c> and</c><00:01:54.280><c> when</c><00:01:54.439><c> you're</c><00:01:55.159><c> posting</c><00:01:55.560><c> let's</c><00:01:55.719><c> say</c>
#
# 00:01:55.830 --> 00:01:55.840 align:start position:0%
# right and when you're posting let's say
#
#
# 00:01:55.840 --> 00:01:58.350 align:start position:0%
# right and when you're posting let's say
# a<00:01:55.960><c> landing</c><00:01:56.280><c> page</c><00:01:56.560><c> or</c><00:01:56.799><c> literally</c><00:01:57.600><c> anything</c>
#
# 00:01:58.350 --> 00:01:58.360 align:start position:0%
# a landing page or literally anything
#
#
# 00:01:58.360 --> 00:02:00.510 align:start position:0%
# a landing page or literally anything
# that<00:01:58.479><c> you</c><00:01:58.680><c> post</c><00:01:58.920><c> online</c><00:01:59.360><c> whether</c><00:01:59.520><c> it's</c><00:01:59.640><c> a</c><00:01:59.840><c> DM</c>
#
# 00:02:00.510 --> 00:02:00.520 align:start position:0%
# that you post online whether it's a DM
#
#
# 00:02:00.520 --> 00:02:03.709 align:start position:0%
# that you post online whether it's a DM
# or<00:02:00.799><c> even</c><00:02:01.000><c> a</c><00:02:01.200><c> text</c><00:02:01.439><c> to</c><00:02:01.560><c> a</c><00:02:01.719><c> friend</c><00:02:02.479><c> or</c><00:02:03.200><c> a</c><00:02:03.399><c> tweet</c>
#
# 00:02:03.709 --> 00:02:03.719 align:start position:0%
# or even a text to a friend or a tweet
#
#
# 00:02:03.719 --> 00:02:05.270 align:start position:0%
# or even a text to a friend or a tweet
# that<00:02:03.840><c> you</c><00:02:04.000><c> post</c><00:02:04.200><c> or</c><00:02:04.320><c> an</c><00:02:04.439><c> Instagram</c><00:02:04.880><c> post</c><00:02:05.079><c> or</c><00:02:05.159><c> a</c>
#
# 00:02:05.270 --> 00:02:05.280 align:start position:0%
# that you post or an Instagram post or a
#
#
# 00:02:05.280 --> 00:02:06.910 align:start position:0%
# that you post or an Instagram post or a
# YouTube<00:02:05.560><c> video</c><00:02:05.759><c> or</c><00:02:05.920><c> whatever</c><00:02:06.479><c> it</c><00:02:06.640><c> has</c><00:02:06.759><c> to</c>
#
# 00:02:06.910 --> 00:02:06.920 align:start position:0%
# YouTube video or whatever it has to
#
#
# 00:02:06.920 --> 00:02:08.749 align:start position:0%
# YouTube video or whatever it has to
# follow<00:02:07.159><c> a</c><00:02:07.320><c> general</c><00:02:07.640><c> persuasive</c><00:02:08.200><c> structure</c>
#
# 00:02:08.749 --> 00:02:08.759 align:start position:0%
# follow a general persuasive structure
#
#
# 00:02:08.759 --> 00:02:11.150 align:start position:0%
# follow a general persuasive structure
# and<00:02:08.959><c> just</c><00:02:09.160><c> as</c><00:02:09.239><c> a</c><00:02:09.399><c> bonus</c><00:02:09.759><c> there</c><00:02:09.920><c> is</c><00:02:10.080><c> a</c><00:02:10.319><c> PDF</c><00:02:10.920><c> link</c>
#
# 00:02:11.150 --> 00:02:11.160 align:start position:0%
# and just as a bonus there is a PDF link
#
#
# 00:02:11.160 --> 00:02:13.869 align:start position:0%
# and just as a bonus there is a PDF link
# to<00:02:11.319><c> the</c><00:02:11.440><c> PDF</c><00:02:12.319><c> in</c><00:02:12.599><c> the</c><00:02:12.800><c> description</c><00:02:13.480><c> that</c><00:02:13.640><c> goes</c>
#
# 00:02:13.869 --> 00:02:13.879 align:start position:0%
# to the PDF in the description that goes
#
#
# 00:02:13.879 --> 00:02:16.229 align:start position:0%
# to the PDF in the description that goes
# over<00:02:14.160><c> my</c><00:02:14.360><c> 10</c><00:02:14.680><c> commandments</c><00:02:15.319><c> of</c><00:02:15.560><c> Engagement</c>
#
# 00:02:16.229 --> 00:02:16.239 align:start position:0%
# over my 10 commandments of Engagement
#
#
# 00:02:16.239 --> 00:02:18.430 align:start position:0%
# over my 10 commandments of Engagement
# that's<00:02:16.519><c> Commandments</c><00:02:17.519><c> and</c><00:02:17.680><c> 32</c><00:02:18.200><c> post</c>
#
# 00:02:18.430 --> 00:02:18.440 align:start position:0%
# that's Commandments and 32 post
#
#
# 00:02:18.440 --> 00:02:19.949 align:start position:0%
# that's Commandments and 32 post
# structures<00:02:18.879><c> that</c><00:02:18.959><c> you</c><00:02:19.040><c> can</c><00:02:19.200><c> emulate</c><00:02:19.720><c> if</c><00:02:19.840><c> you</c>
#
# 00:02:19.949 --> 00:02:19.959 align:start position:0%
# structures that you can emulate if you
#
#
# 00:02:19.959 --> 00:02:21.630 align:start position:0%
# structures that you can emulate if you
# want<00:02:20.160><c> to</c><00:02:20.400><c> increase</c><00:02:20.840><c> the</c><00:02:21.000><c> power</c><00:02:21.319><c> of</c><00:02:21.440><c> your</c>
#
# 00:02:21.630 --> 00:02:21.640 align:start position:0%
# want to increase the power of your
#
#
# 00:02:21.640 --> 00:02:23.190 align:start position:0%
# want to increase the power of your
# writing<00:02:22.319><c> there's</c><00:02:22.519><c> no</c><00:02:22.680><c> pitch</c><00:02:22.879><c> in</c><00:02:23.040><c> there</c>
#
# 00:02:23.190 --> 00:02:23.200 align:start position:0%
# writing there's no pitch in there
#
#
# 00:02:23.200 --> 00:02:24.550 align:start position:0%
# writing there's no pitch in there
# there's<00:02:23.360><c> no</c><00:02:23.519><c> nothing</c><00:02:23.800><c> is</c><00:02:23.920><c> just</c><00:02:24.080><c> download</c><00:02:24.400><c> the</c>
#
# 00:02:24.550 --> 00:02:24.560 align:start position:0%
# there's no nothing is just download the
#
#
# 00:02:24.560 --> 00:02:27.309 align:start position:0%
# there's no nothing is just download the
# PDF<00:02:25.000><c> use</c><00:02:25.200><c> it</c><00:02:25.720><c> have</c><00:02:25.879><c> it</c><00:02:26.080><c> open</c><00:02:26.480><c> alongside</c><00:02:27.160><c> while</c>
#
# 00:02:27.309 --> 00:02:27.319 align:start position:0%
# PDF use it have it open alongside while
#
#
# 00:02:27.319 --> 00:02:29.390 align:start position:0%
# PDF use it have it open alongside while
# you<00:02:27.480><c> write</c><00:02:27.760><c> content</c><00:02:28.160><c> or</c><00:02:28.480><c> literally</c><00:02:28.959><c> anything</c>
#
# 00:02:29.390 --> 00:02:29.400 align:start position:0%
# you write content or literally anything
#
#
# 00:02:29.400 --> 00:02:31.509 align:start position:0%
# you write content or literally anything
# so<00:02:29.599><c> let</c><00:02:29.840><c> let's</c><00:02:30.040><c> finally</c><00:02:30.599><c> dive</c><00:02:30.800><c> in</c><00:02:31.280><c> people</c>
#
# 00:02:31.509 --> 00:02:31.519 align:start position:0%
# so let let's finally dive in people
#
#
# 00:02:31.519 --> 00:02:33.270 align:start position:0%
# so let let's finally dive in people
# don't<00:02:31.840><c> remember</c><00:02:32.239><c> what</c><00:02:32.360><c> you</c><00:02:32.560><c> say</c><00:02:33.120><c> they</c>
#
# 00:02:33.270 --> 00:02:33.280 align:start position:0%
# don't remember what you say they
#
#
# 00:02:33.280 --> 00:02:35.430 align:start position:0%
# don't remember what you say they
# remember<00:02:33.680><c> how</c><00:02:33.800><c> you</c><00:02:33.959><c> make</c><00:02:34.120><c> them</c><00:02:34.319><c> feel</c><00:02:35.120><c> this</c><00:02:35.239><c> is</c>
#
# 00:02:35.430 --> 00:02:35.440 align:start position:0%
# remember how you make them feel this is
#
#
# 00:02:35.440 --> 00:02:37.470 align:start position:0%
# remember how you make them feel this is
# worth<00:02:35.720><c> repeating</c><00:02:36.360><c> humans</c><00:02:36.720><c> are</c><00:02:37.000><c> emotional</c>
#
# 00:02:37.470 --> 00:02:37.480 align:start position:0%
# worth repeating humans are emotional
#
#
# 00:02:37.480 --> 00:02:40.589 align:start position:0%
# worth repeating humans are emotional
# beings<00:02:38.040><c> not</c><00:02:38.280><c> logical</c><00:02:39.000><c> 99%</c><00:02:39.800><c> of</c><00:02:39.920><c> the</c><00:02:40.080><c> population</c>
#
# 00:02:40.589 --> 00:02:40.599 align:start position:0%
# beings not logical 99% of the population
#
#
# 00:02:40.599 --> 00:02:41.990 align:start position:0%
# beings not logical 99% of the population
# have<00:02:40.720><c> not</c><00:02:40.920><c> developed</c><00:02:41.440><c> themselves</c><00:02:41.680><c> to</c><00:02:41.879><c> the</c>
#
# 00:02:41.990 --> 00:02:42.000 align:start position:0%
# have not developed themselves to the
#
#
# 00:02:42.000 --> 00:02:44.229 align:start position:0%
# have not developed themselves to the
# point<00:02:42.239><c> of</c><00:02:42.400><c> being</c><00:02:42.680><c> free</c><00:02:43.000><c> from</c><00:02:43.319><c> or</c><00:02:43.519><c> in</c><00:02:43.760><c> control</c>
#
# 00:02:44.229 --> 00:02:44.239 align:start position:0%
# point of being free from or in control
#
#
# 00:02:44.239 --> 00:02:46.869 align:start position:0%
# point of being free from or in control
# of<00:02:44.720><c> their</c><00:02:44.959><c> ego</c><00:02:45.640><c> that</c><00:02:45.800><c> is</c><00:02:45.920><c> the</c><00:02:46.120><c> foundation</c><00:02:46.680><c> of</c>
#
# 00:02:46.869 --> 00:02:46.879 align:start position:0%
# of their ego that is the foundation of
#
#
# 00:02:46.879 --> 00:02:49.030 align:start position:0%
# of their ego that is the foundation of
# capturing<00:02:47.280><c> and</c><00:02:47.440><c> holding</c><00:02:47.760><c> attention</c><00:02:48.560><c> poking</c>
#
# 00:02:49.030 --> 00:02:49.040 align:start position:0%
# capturing and holding attention poking
#
#
# 00:02:49.040 --> 00:02:51.790 align:start position:0%
# capturing and holding attention poking
# your<00:02:49.200><c> reader</c><00:02:49.920><c> ego</c><00:02:50.440><c> you</c><00:02:50.560><c> can</c><00:02:50.720><c> feed</c><00:02:51.040><c> it</c><00:02:51.400><c> or</c><00:02:51.599><c> make</c>
#
# 00:02:51.790 --> 00:02:51.800 align:start position:0%
# your reader ego you can feed it or make
#
#
# 00:02:51.800 --> 00:02:53.910 align:start position:0%
# your reader ego you can feed it or make
# them<00:02:51.959><c> feel</c><00:02:52.319><c> good</c><00:02:52.720><c> or</c><00:02:52.879><c> you</c><00:02:52.959><c> can</c><00:02:53.120><c> starve</c><00:02:53.480><c> it</c><00:02:53.680><c> or</c>
#
# 00:02:53.910 --> 00:02:53.920 align:start position:0%
# them feel good or you can starve it or
#
#
# 00:02:53.920 --> 00:02:55.710 align:start position:0%
# them feel good or you can starve it or
# make<00:02:54.080><c> them</c><00:02:54.239><c> feel</c><00:02:54.560><c> bad</c><00:02:55.040><c> if</c><00:02:55.159><c> you</c><00:02:55.280><c> can</c><00:02:55.440><c> take</c>
#
# 00:02:55.710 --> 00:02:55.720 align:start position:0%
# make them feel bad if you can take
#
#
# 00:02:55.720 --> 00:02:57.910 align:start position:0%
# make them feel bad if you can take
# people<00:02:56.000><c> on</c><00:02:56.159><c> an</c><00:02:56.360><c> emotional</c><00:02:56.840><c> journey</c><00:02:57.239><c> of</c><00:02:57.480><c> love</c>
#
# 00:02:57.910 --> 00:02:57.920 align:start position:0%
# people on an emotional journey of love
#
#
# 00:02:57.920 --> 00:03:00.630 align:start position:0%
# people on an emotional journey of love
# hate<00:02:58.360><c> excitement</c><00:02:58.920><c> deceit</c><00:02:59.760><c> calmness</c><00:03:00.200><c> and</c><00:03:00.400><c> any</c>
#
# 00:03:00.630 --> 00:03:00.640 align:start position:0%
# hate excitement deceit calmness and any
#
#
# 00:03:00.640 --> 00:03:02.589 align:start position:0%
# hate excitement deceit calmness and any
# other<00:03:00.920><c> emotion</c><00:03:01.319><c> that</c><00:03:01.519><c> eventually</c><00:03:01.959><c> ends</c><00:03:02.280><c> in</c><00:03:02.400><c> a</c>
#
# 00:03:02.589 --> 00:03:02.599 align:start position:0%
# other emotion that eventually ends in a
#
#
# 00:03:02.599 --> 00:03:04.710 align:start position:0%
# other emotion that eventually ends in a
# benefit<00:03:02.959><c> for</c><00:03:03.239><c> their</c><00:03:03.480><c> life</c><00:03:03.920><c> you</c><00:03:04.080><c> have</c><00:03:04.280><c> mastered</c>
#
# 00:03:04.710 --> 00:03:04.720 align:start position:0%
# benefit for their life you have mastered
#
#
# 00:03:04.720 --> 00:03:07.910 align:start position:0%
# benefit for their life you have mastered
# the<00:03:04.879><c> art</c><00:03:05.239><c> of</c><00:03:05.480><c> content</c><00:03:05.959><c> creation</c><00:03:06.760><c> life</c><00:03:07.319><c> is</c>
#
# 00:03:07.910 --> 00:03:07.920 align:start position:0%
# the art of content creation life is
#
#
# 00:03:07.920 --> 00:03:11.509 align:start position:0%
# the art of content creation life is
# story<00:03:08.760><c> song</c><00:03:09.280><c> is</c><00:03:09.560><c> story</c><00:03:10.120><c> the</c><00:03:10.319><c> universe</c><00:03:11.000><c> or</c>
#
# 00:03:11.509 --> 00:03:11.519 align:start position:0%
# story song is story the universe or
#
#
# 00:03:11.519 --> 00:03:15.190 align:start position:0%
# story song is story the universe or
# Universe<00:03:12.519><c> one</c><00:03:13.159><c> song</c><00:03:13.760><c> architecture</c><00:03:14.599><c> music</c>
#
# 00:03:15.190 --> 00:03:15.200 align:start position:0%
# Universe one song architecture music
#
#
# 00:03:15.200 --> 00:03:17.149 align:start position:0%
# Universe one song architecture music
# plant<00:03:15.519><c> life</c><00:03:15.879><c> and</c><00:03:16.120><c> everything</c><00:03:16.519><c> else</c><00:03:16.799><c> follow</c>
#
# 00:03:17.149 --> 00:03:17.159 align:start position:0%
# plant life and everything else follow
#
#
# 00:03:17.159 --> 00:03:18.990 align:start position:0%
# plant life and everything else follow
# the<00:03:17.319><c> universal</c><00:03:17.920><c> principles</c><00:03:18.400><c> of</c><00:03:18.599><c> highs</c><00:03:18.799><c> and</c>
#
# 00:03:18.990 --> 00:03:19.000 align:start position:0%
# the universal principles of highs and
#
#
# 00:03:19.000 --> 00:03:21.750 align:start position:0%
# the universal principles of highs and
# lows<00:03:19.599><c> creation</c><00:03:19.959><c> and</c><00:03:20.200><c> destruction</c><00:03:21.120><c> growth</c><00:03:21.519><c> and</c>
#
# 00:03:21.750 --> 00:03:21.760 align:start position:0%
# lows creation and destruction growth and
#
#
# 00:03:21.760 --> 00:03:24.470 align:start position:0%
# lows creation and destruction growth and
# death<00:03:22.280><c> Etc</c><00:03:22.959><c> humans</c><00:03:23.319><c> make</c><00:03:23.720><c> sense</c><00:03:23.920><c> of</c><00:03:24.080><c> the</c><00:03:24.200><c> world</c>
#
# 00:03:24.470 --> 00:03:24.480 align:start position:0%
# death Etc humans make sense of the world
#
#
# 00:03:24.480 --> 00:03:27.110 align:start position:0%
# death Etc humans make sense of the world
# in<00:03:24.760><c> stories</c><00:03:25.519><c> your</c><00:03:25.799><c> job</c><00:03:26.120><c> is</c><00:03:26.239><c> to</c><00:03:26.440><c> use</c><00:03:26.720><c> the</c><00:03:26.879><c> power</c>
#
# 00:03:27.110 --> 00:03:27.120 align:start position:0%
# in stories your job is to use the power
#
#
# 00:03:27.120 --> 00:03:29.990 align:start position:0%
# in stories your job is to use the power
# of<00:03:27.319><c> word</c><00:03:27.799><c> to</c><00:03:28.000><c> make</c><00:03:28.319><c> people</c><00:03:28.840><c> feel</c><00:03:29.239><c> something</c>
#
# 00:03:29.990 --> 00:03:30.000 align:start position:0%
# of word to make people feel something
#
#
# 00:03:30.000 --> 00:03:32.429 align:start position:0%
# of word to make people feel something
# stories<00:03:30.480><c> mimic</c><00:03:30.920><c> the</c><00:03:31.120><c> natural</c><00:03:31.599><c> highs</c><00:03:31.840><c> and</c><00:03:32.040><c> lows</c>
#
# 00:03:32.429 --> 00:03:32.439 align:start position:0%
# stories mimic the natural highs and lows
#
#
# 00:03:32.439 --> 00:03:34.869 align:start position:0%
# stories mimic the natural highs and lows
# of<00:03:32.720><c> emotion</c><00:03:33.439><c> I</c><00:03:33.599><c> have</c><00:03:33.799><c> an</c><00:03:34.000><c> entire</c><00:03:34.439><c> chapter</c>
#
# 00:03:34.869 --> 00:03:34.879 align:start position:0%
# of emotion I have an entire chapter
#
#
# 00:03:34.879 --> 00:03:37.270 align:start position:0%
# of emotion I have an entire chapter
# dedicated<00:03:35.400><c> to</c><00:03:35.920><c> the</c><00:03:36.080><c> universe</c><00:03:36.640><c> which</c><00:03:36.760><c> is</c><00:03:36.959><c> very</c>
#
# 00:03:37.270 --> 00:03:37.280 align:start position:0%
# dedicated to the universe which is very
#
#
# 00:03:37.280 --> 00:03:40.270 align:start position:0%
# dedicated to the universe which is very
# big<00:03:37.519><c> picture</c><00:03:38.400><c> understanding</c><00:03:38.879><c> of</c><00:03:39.480><c> what</c><00:03:39.720><c> truth</c>
#
# 00:03:40.270 --> 00:03:40.280 align:start position:0%
# big picture understanding of what truth
#
#
# 00:03:40.280 --> 00:03:42.830 align:start position:0%
# big picture understanding of what truth
# is<00:03:40.879><c> in</c><00:03:41.040><c> my</c><00:03:41.239><c> book</c><00:03:41.480><c> The</c><00:03:41.599><c> Art</c><00:03:41.799><c> of</c><00:03:42.000><c> focus</c><00:03:42.480><c> and</c><00:03:42.599><c> then</c>
#
# 00:03:42.830 --> 00:03:42.840 align:start position:0%
# is in my book The Art of focus and then
#
#
# 00:03:42.840 --> 00:03:44.390 align:start position:0%
# is in my book The Art of focus and then
# every<00:03:43.080><c> other</c><00:03:43.360><c> chapter</c><00:03:43.760><c> that's</c><00:03:43.959><c> one</c><00:03:44.080><c> of</c><00:03:44.200><c> the</c>
#
# 00:03:44.390 --> 00:03:44.400 align:start position:0%
# every other chapter that's one of the
#
#
# 00:03:44.400 --> 00:03:46.710 align:start position:0%
# every other chapter that's one of the
# primary<00:03:44.760><c> chapters</c><00:03:45.120><c> that</c><00:03:45.280><c> helps</c><00:03:45.480><c> you</c><00:03:45.720><c> frame</c>
#
# 00:03:46.710 --> 00:03:46.720 align:start position:0%
# primary chapters that helps you frame
#
#
# 00:03:46.720 --> 00:03:49.509 align:start position:0%
# primary chapters that helps you frame
# business<00:03:47.519><c> and</c><00:03:48.040><c> the</c><00:03:48.280><c> the</c><00:03:48.400><c> new</c><00:03:48.680><c> economy</c><00:03:49.239><c> how</c><00:03:49.360><c> to</c>
#
# 00:03:49.509 --> 00:03:49.519 align:start position:0%
# business and the the new economy how to
#
#
# 00:03:49.519 --> 00:03:51.149 align:start position:0%
# business and the the new economy how to
# acquire<00:03:49.920><c> skills</c><00:03:50.319><c> how</c><00:03:50.439><c> to</c><00:03:50.920><c> understand</c>
#
# 00:03:51.149 --> 00:03:51.159 align:start position:0%
# acquire skills how to understand
#
#
# 00:03:51.159 --> 00:03:54.069 align:start position:0%
# acquire skills how to understand
# yourself<00:03:51.720><c> how</c><00:03:51.840><c> to</c><00:03:52.000><c> reinvent</c><00:03:52.480><c> yourself</c><00:03:53.239><c> it</c><00:03:53.439><c> all</c>
#
# 00:03:54.069 --> 00:03:54.079 align:start position:0%
# yourself how to reinvent yourself it all
#
#
# 00:03:54.079 --> 00:03:56.509 align:start position:0%
# yourself how to reinvent yourself it all
# mimics<00:03:54.720><c> Universal</c><00:03:55.319><c> patterns</c><00:03:55.680><c> and</c><00:03:55.840><c> once</c><00:03:56.000><c> you</c>
#
# 00:03:56.509 --> 00:03:56.519 align:start position:0%
# mimics Universal patterns and once you
#
#
# 00:03:56.519 --> 00:03:58.390 align:start position:0%
# mimics Universal patterns and once you
# understand<00:03:56.760><c> that</c><00:03:57.120><c> you</c><00:03:57.280><c> master</c><00:03:57.680><c> yourself</c><00:03:58.280><c> and</c>
#
# 00:03:58.390 --> 00:03:58.400 align:start position:0%
# understand that you master yourself and
#
#
# 00:03:58.400 --> 00:04:00.069 align:start position:0%
# understand that you master yourself and
# then<00:03:58.519><c> you</c><00:03:58.640><c> can</c><00:03:58.799><c> Master</c><00:03:59.120><c> the</c><00:03:59.280><c> world</c><00:03:59.760><c> so</c><00:03:59.920><c> if</c><00:04:00.000><c> you</c>
#
# 00:04:00.069 --> 00:04:00.079 align:start position:0%
# then you can Master the world so if you
#
#
# 00:04:00.079 --> 00:04:01.589 align:start position:0%
# then you can Master the world so if you
# want<00:04:00.239><c> to</c><00:04:00.400><c> pre-order</c><00:04:00.879><c> the</c><00:04:01.000><c> book</c><00:04:01.200><c> go</c><00:04:01.319><c> to</c><00:04:01.480><c> the</c>
#
# 00:04:01.589 --> 00:04:01.599 align:start position:0%
# want to pre-order the book go to the
#
#
# 00:04:01.599 --> 00:04:03.270 align:start position:0%
# want to pre-order the book go to the
# first<00:04:01.879><c> link</c><00:04:02.280><c> in</c><00:04:02.400><c> the</c><00:04:02.560><c> description</c><00:04:03.159><c> the</c>
#
# 00:04:03.270 --> 00:04:03.280 align:start position:0%
# first link in the description the
#
#
# 00:04:03.280 --> 00:04:05.190 align:start position:0%
# first link in the description the
# keepsake<00:04:03.799><c> box</c><00:04:04.040><c> is</c><00:04:04.200><c> still</c><00:04:04.439><c> live</c><00:04:04.720><c> and</c><00:04:04.879><c> there</c><00:04:04.959><c> are</c>
#
# 00:04:05.190 --> 00:04:05.200 align:start position:0%
# keepsake box is still live and there are
#
#
# 00:04:05.200 --> 00:04:07.710 align:start position:0%
# keepsake box is still live and there are
# only<00:04:05.519><c> 2,000</c><00:04:06.159><c> copies</c><00:04:06.799><c> of</c><00:04:07.000><c> that</c><00:04:07.239><c> that</c><00:04:07.360><c> we</c><00:04:07.480><c> are</c>
#
# 00:04:07.710 --> 00:04:07.720 align:start position:0%
# only 2,000 copies of that that we are
#
#
# 00:04:07.720 --> 00:04:10.190 align:start position:0%
# only 2,000 copies of that that we are
# printing<00:04:08.439><c> before</c><00:04:08.920><c> the</c><00:04:09.040><c> paperback</c><00:04:09.560><c> goes</c><00:04:09.760><c> out</c>
#
# 00:04:10.190 --> 00:04:10.200 align:start position:0%
# printing before the paperback goes out
#
#
# 00:04:10.200 --> 00:04:12.110 align:start position:0%
# printing before the paperback goes out
# early<00:04:10.599><c> next</c><00:04:10.840><c> year</c><00:04:11.239><c> so</c><00:04:11.439><c> if</c><00:04:11.519><c> you</c><00:04:11.599><c> want</c><00:04:11.720><c> to</c><00:04:11.840><c> be</c><00:04:11.959><c> the</c>
#
# 00:04:12.110 --> 00:04:12.120 align:start position:0%
# early next year so if you want to be the
#
#
# 00:04:12.120 --> 00:04:14.149 align:start position:0%
# early next year so if you want to be the
# first<00:04:12.400><c> to</c><00:04:12.599><c> read</c><00:04:12.840><c> it</c><00:04:13.120><c> you</c><00:04:13.239><c> get</c><00:04:13.480><c> instant</c><00:04:13.920><c> access</c>
#
# 00:04:14.149 --> 00:04:14.159 align:start position:0%
# first to read it you get instant access
#
#
# 00:04:14.159 --> 00:04:15.670 align:start position:0%
# first to read it you get instant access
# to<00:04:14.360><c> the</c><00:04:14.560><c> digital</c><00:04:14.920><c> version</c><00:04:15.239><c> when</c><00:04:15.360><c> you</c><00:04:15.439><c> do</c>
#
# 00:04:15.670 --> 00:04:15.680 align:start position:0%
# to the digital version when you do
#
#
# 00:04:15.680 --> 00:04:17.789 align:start position:0%
# to the digital version when you do
# pre-order<00:04:16.079><c> the</c><00:04:16.199><c> keepsake</c><00:04:16.680><c> box</c><00:04:17.160><c> so</c><00:04:17.320><c> we</c>
#
# 00:04:17.789 --> 00:04:17.799 align:start position:0%
# pre-order the keepsake box so we
#
#
# 00:04:17.799 --> 00:04:19.430 align:start position:0%
# pre-order the keepsake box so we
# understand<00:04:18.079><c> the</c><00:04:18.320><c> importance</c><00:04:18.840><c> and</c><00:04:19.040><c> kind</c><00:04:19.160><c> of</c>
#
# 00:04:19.430 --> 00:04:19.440 align:start position:0%
# understand the importance and kind of
#
#
# 00:04:19.440 --> 00:04:21.469 align:start position:0%
# understand the importance and kind of
# how<00:04:19.639><c> to</c><00:04:19.919><c> persuade</c><00:04:20.440><c> by</c><00:04:20.600><c> mimicking</c><00:04:21.320><c> the</c>
#
# 00:04:21.469 --> 00:04:21.479 align:start position:0%
# how to persuade by mimicking the
#
#
# 00:04:21.479 --> 00:04:22.990 align:start position:0%
# how to persuade by mimicking the
# patterns<00:04:21.799><c> of</c><00:04:21.959><c> the</c><00:04:22.040><c> universe</c><00:04:22.520><c> the</c><00:04:22.639><c> highs</c><00:04:22.840><c> and</c>
#
# 00:04:22.990 --> 00:04:23.000 align:start position:0%
# patterns of the universe the highs and
#
#
# 00:04:23.000 --> 00:04:25.350 align:start position:0%
# patterns of the universe the highs and
# lows<00:04:23.320><c> the</c><00:04:23.440><c> emotions</c><00:04:24.080><c> that</c><00:04:24.560><c> give</c><00:04:24.919><c> people</c>
#
# 00:04:25.350 --> 00:04:25.360 align:start position:0%
# lows the emotions that give people
#
#
# 00:04:25.360 --> 00:04:28.150 align:start position:0%
# lows the emotions that give people
# meaning<00:04:25.960><c> and</c><00:04:26.680><c> feeling</c><00:04:27.120><c> in</c><00:04:27.320><c> this</c><00:04:27.560><c> life</c><00:04:27.919><c> because</c>
#
# 00:04:28.150 --> 00:04:28.160 align:start position:0%
# meaning and feeling in this life because
#
#
# 00:04:28.160 --> 00:04:30.110 align:start position:0%
# meaning and feeling in this life because
# if<00:04:28.320><c> you</c><00:04:28.680><c> if</c><00:04:28.759><c> you're</c><00:04:28.919><c> just</c><00:04:29.080><c> happy</c><00:04:29.320><c> all</c><00:04:29.440><c> the</c><00:04:29.759><c> time</c>
#
# 00:04:30.110 --> 00:04:30.120 align:start position:0%
# if you if you're just happy all the time
#
#
# 00:04:30.120 --> 00:04:31.790 align:start position:0%
# if you if you're just happy all the time
# this<00:04:30.240><c> is</c><00:04:30.360><c> why</c><00:04:30.560><c> happiness</c><00:04:30.919><c> is</c><00:04:31.080><c> kind</c><00:04:31.199><c> of</c><00:04:31.320><c> a</c><00:04:31.479><c> false</c>
#
# 00:04:31.790 --> 00:04:31.800 align:start position:0%
# this is why happiness is kind of a false
#
#
# 00:04:31.800 --> 00:04:33.990 align:start position:0%
# this is why happiness is kind of a false
# metric<00:04:32.160><c> to</c><00:04:32.880><c> pursue</c><00:04:33.360><c> is</c><00:04:33.520><c> because</c><00:04:33.720><c> when</c><00:04:33.800><c> you're</c>
#
# 00:04:33.990 --> 00:04:34.000 align:start position:0%
# metric to pursue is because when you're
#
#
# 00:04:34.000 --> 00:04:35.590 align:start position:0%
# metric to pursue is because when you're
# happy<00:04:34.199><c> all</c><00:04:34.360><c> the</c><00:04:34.520><c> time</c><00:04:35.000><c> that's</c><00:04:35.240><c> that's</c><00:04:35.400><c> not</c>
#
# 00:04:35.590 --> 00:04:35.600 align:start position:0%
# happy all the time that's that's not
#
#
# 00:04:35.600 --> 00:04:37.510 align:start position:0%
# happy all the time that's that's not
# happiness<00:04:36.199><c> like</c><00:04:36.360><c> you're</c><00:04:36.560><c> just</c><00:04:36.800><c> kind</c><00:04:36.919><c> of</c><00:04:37.160><c> stuck</c>
#
# 00:04:37.510 --> 00:04:37.520 align:start position:0%
# happiness like you're just kind of stuck
#
#
# 00:04:37.520 --> 00:04:39.590 align:start position:0%
# happiness like you're just kind of stuck
# there<00:04:37.960><c> it's</c><00:04:38.160><c> normal</c><00:04:38.919><c> equilibrium</c>
#
# 00:04:39.590 --> 00:04:39.600 align:start position:0%
# there it's normal equilibrium
#
#
# 00:04:39.600 --> 00:04:42.350 align:start position:0%
# there it's normal equilibrium
# homeostasis<00:04:40.520><c> eventually</c><00:04:40.880><c> it</c><00:04:41.039><c> balances</c><00:04:41.600><c> out</c>
#
# 00:04:42.350 --> 00:04:42.360 align:start position:0%
# homeostasis eventually it balances out
#
#
# 00:04:42.360 --> 00:04:45.189 align:start position:0%
# homeostasis eventually it balances out
# to<00:04:43.160><c> what</c><00:04:43.320><c> is</c><00:04:43.639><c> normal</c><00:04:44.000><c> or</c><00:04:44.160><c> boring</c><00:04:44.520><c> so</c><00:04:44.680><c> if</c><00:04:44.800><c> you're</c>
#
# 00:04:45.189 --> 00:04:45.199 align:start position:0%
# to what is normal or boring so if you're
#
#
# 00:04:45.199 --> 00:04:47.390 align:start position:0%
# to what is normal or boring so if you're
# at<00:04:45.400><c> this</c><00:04:45.639><c> level</c><00:04:45.840><c> of</c><00:04:46.000><c> Happiness</c><00:04:46.360><c> all</c><00:04:46.520><c> the</c><00:04:46.680><c> time</c>
#
# 00:04:47.390 --> 00:04:47.400 align:start position:0%
# at this level of Happiness all the time
#
#
# 00:04:47.400 --> 00:04:49.070 align:start position:0%
# at this level of Happiness all the time
# then<00:04:47.600><c> your</c><00:04:47.759><c> Baseline</c><00:04:48.199><c> increases</c><00:04:48.680><c> to</c><00:04:48.880><c> that</c><00:04:49.000><c> and</c>
#
# 00:04:49.070 --> 00:04:49.080 align:start position:0%
# then your Baseline increases to that and
#
#
# 00:04:49.080 --> 00:04:50.590 align:start position:0%
# then your Baseline increases to that and
# you<00:04:49.199><c> are</c><00:04:49.360><c> no</c><00:04:49.520><c> longer</c><00:04:49.840><c> happy</c><00:04:50.199><c> so</c><00:04:50.320><c> you</c><00:04:50.400><c> have</c><00:04:50.520><c> to</c>
#
# 00:04:50.590 --> 00:04:50.600 align:start position:0%
# you are no longer happy so you have to
#
#
# 00:04:50.600 --> 00:04:52.390 align:start position:0%
# you are no longer happy so you have to
# pursue<00:04:50.960><c> more</c><00:04:51.240><c> and</c><00:04:51.360><c> more</c><00:04:51.560><c> and</c><00:04:51.680><c> more</c><00:04:52.080><c> that's</c><00:04:52.240><c> all</c>
#
# 00:04:52.390 --> 00:04:52.400 align:start position:0%
# pursue more and more and more that's all
#
#
# 00:04:52.400 --> 00:04:54.350 align:start position:0%
# pursue more and more and more that's all
# to<00:04:52.600><c> say</c><00:04:53.000><c> that</c><00:04:53.160><c> human</c><00:04:53.759><c> understanding</c><00:04:53.960><c> is</c><00:04:54.120><c> based</c>
#
# 00:04:54.350 --> 00:04:54.360 align:start position:0%
# to say that human understanding is based
#
#
# 00:04:54.360 --> 00:04:55.909 align:start position:0%
# to say that human understanding is based
# on<00:04:54.440><c> the</c><00:04:54.560><c> highs</c><00:04:54.720><c> and</c><00:04:54.840><c> lows</c><00:04:55.080><c> of</c><00:04:55.280><c> life</c><00:04:55.680><c> and</c><00:04:55.800><c> we</c>
#
# ...
#
# 00:25:59.950 --> 00:25:59.960 align:start position:0%
# get that I like that idea how does it
#
#
# 00:25:59.960 --> 00:26:01.470 align:start position:0%
# get that I like that idea how does it
# make<00:26:00.120><c> sense</c><00:26:00.320><c> to</c><00:26:00.440><c> me</c><00:26:00.840><c> I'm</c><00:26:00.919><c> going</c><00:26:01.039><c> to</c><00:26:01.120><c> share</c><00:26:01.360><c> that</c>
#
# 00:26:01.470 --> 00:26:01.480 align:start position:0%
# make sense to me I'm going to share that
#
#
# 00:26:01.480 --> 00:26:03.470 align:start position:0%
# make sense to me I'm going to share that
# with<00:26:01.640><c> other</c><00:26:01.840><c> people</c><00:26:02.559><c> simple</c><00:26:02.840><c> as</c><00:26:03.000><c> that</c><00:26:03.360><c> the</c>
#
# 00:26:03.470 --> 00:26:03.480 align:start position:0%
# with other people simple as that the
#
#
# 00:26:03.480 --> 00:26:05.190 align:start position:0%
# with other people simple as that the
# second<00:26:03.799><c> thing</c><00:26:04.039><c> that</c><00:26:04.200><c> creates</c><00:26:04.520><c> engagement</c><00:26:05.080><c> is</c>
#
# 00:26:05.190 --> 00:26:05.200 align:start position:0%
# second thing that creates engagement is
#
#
# 00:26:05.200 --> 00:26:07.269 align:start position:0%
# second thing that creates engagement is
# the<00:26:05.279><c> feeling</c><00:26:05.679><c> that</c><00:26:05.799><c> comes</c><00:26:06.039><c> from</c><00:26:06.320><c> inspiration</c>
#
# 00:26:07.269 --> 00:26:07.279 align:start position:0%
# the feeling that comes from inspiration
#
#
# 00:26:07.279 --> 00:26:09.350 align:start position:0%
# the feeling that comes from inspiration
# inspiration<00:26:07.799><c> is</c><00:26:08.039><c> different</c><00:26:08.480><c> from</c><00:26:08.679><c> motivation</c>
#
# 00:26:09.350 --> 00:26:09.360 align:start position:0%
# inspiration is different from motivation
#
#
# 00:26:09.360 --> 00:26:10.870 align:start position:0%
# inspiration is different from motivation
# you're<00:26:09.600><c> helping</c><00:26:09.919><c> people</c><00:26:10.200><c> connect</c><00:26:10.480><c> the</c><00:26:10.600><c> dots</c>
#
# 00:26:10.870 --> 00:26:10.880 align:start position:0%
# you're helping people connect the dots
#
#
# 00:26:10.880 --> 00:26:12.590 align:start position:0%
# you're helping people connect the dots
# on<00:26:11.039><c> their</c><00:26:11.200><c> own</c><00:26:11.640><c> giving</c><00:26:11.880><c> them</c><00:26:12.000><c> the</c><00:26:12.159><c> clarity</c><00:26:12.480><c> to</c>
#
# 00:26:12.590 --> 00:26:12.600 align:start position:0%
# on their own giving them the clarity to
#
#
# 00:26:12.600 --> 00:26:13.950 align:start position:0%
# on their own giving them the clarity to
# make<00:26:12.760><c> their</c><00:26:12.880><c> own</c><00:26:13.080><c> decisions</c><00:26:13.559><c> and</c><00:26:13.679><c> change</c>
#
# 00:26:13.950 --> 00:26:13.960 align:start position:0%
# make their own decisions and change
#
#
# 00:26:13.960 --> 00:26:15.789 align:start position:0%
# make their own decisions and change
# their<00:26:14.120><c> behavior</c><00:26:14.799><c> people</c><00:26:15.039><c> feel</c><00:26:15.399><c> good</c><00:26:15.640><c> when</c>
#
# 00:26:15.789 --> 00:26:15.799 align:start position:0%
# their behavior people feel good when
#
#
# 00:26:15.799 --> 00:26:17.470 align:start position:0%
# their behavior people feel good when
# they<00:26:15.960><c> think</c><00:26:16.200><c> they</c><00:26:16.360><c> came</c><00:26:16.559><c> up</c><00:26:16.679><c> with</c><00:26:16.799><c> the</c><00:26:16.960><c> answer</c>
#
# 00:26:17.470 --> 00:26:17.480 align:start position:0%
# they think they came up with the answer
#
#
# 00:26:17.480 --> 00:26:19.029 align:start position:0%
# they think they came up with the answer
# themselves<00:26:17.880><c> but</c><00:26:18.000><c> will</c><00:26:18.200><c> still</c><00:26:18.480><c> attribute</c><00:26:18.919><c> that</c>
#
# 00:26:19.029 --> 00:26:19.039 align:start position:0%
# themselves but will still attribute that
#
#
# 00:26:19.039 --> 00:26:20.990 align:start position:0%
# themselves but will still attribute that
# feeling<00:26:19.360><c> to</c><00:26:19.600><c> you</c><00:26:20.159><c> the</c><00:26:20.320><c> third</c><00:26:20.600><c> thing</c><00:26:20.840><c> that</c>
#
# 00:26:20.990 --> 00:26:21.000 align:start position:0%
# feeling to you the third thing that
#
#
# 00:26:21.000 --> 00:26:22.789 align:start position:0%
# feeling to you the third thing that
# creates<00:26:21.279><c> engagement</c><00:26:21.880><c> is</c><00:26:22.039><c> the</c><00:26:22.200><c> feeling</c><00:26:22.600><c> that</c>
#
# 00:26:22.789 --> 00:26:22.799 align:start position:0%
# creates engagement is the feeling that
#
#
# 00:26:22.799 --> 00:26:24.590 align:start position:0%
# creates engagement is the feeling that
# comes<00:26:23.080><c> with</c><00:26:23.320><c> entertainment</c><00:26:24.159><c> can</c><00:26:24.279><c> you</c><00:26:24.399><c> throw</c>
#
# 00:26:24.590 --> 00:26:24.600 align:start position:0%
# comes with entertainment can you throw
#
#
# 00:26:24.600 --> 00:26:26.590 align:start position:0%
# comes with entertainment can you throw
# in<00:26:24.720><c> a</c><00:26:24.880><c> joke</c><00:26:25.279><c> meme</c><00:26:25.559><c> or</c><00:26:25.760><c> interesting</c><00:26:26.240><c> point</c><00:26:26.440><c> of</c>
#
# 00:26:26.590 --> 00:26:26.600 align:start position:0%
# in a joke meme or interesting point of
#
#
# 00:26:26.600 --> 00:26:28.350 align:start position:0%
# in a joke meme or interesting point of
# view<00:26:26.960><c> when</c><00:26:27.039><c> you</c><00:26:27.159><c> watch</c><00:26:27.320><c> a</c><00:26:27.679><c> movie</c><00:26:28.080><c> you</c><00:26:28.200><c> are</c>
#
# 00:26:28.350 --> 00:26:28.360 align:start position:0%
# view when you watch a movie you are
#
#
# 00:26:28.360 --> 00:26:29.870 align:start position:0%
# view when you watch a movie you are
# entertained<00:26:28.840><c> through</c><00:26:29.080><c> humor</c><00:26:29.440><c> drama</c>
#
# 00:26:29.870 --> 00:26:29.880 align:start position:0%
# entertained through humor drama
#
#
# 00:26:29.880 --> 00:26:31.789 align:start position:0%
# entertained through humor drama
# emotional<00:26:30.279><c> parts</c><00:26:30.520><c> of</c><00:26:30.640><c> the</c><00:26:30.760><c> story</c><00:26:31.279><c> and</c><00:26:31.480><c> battles</c>
#
# 00:26:31.789 --> 00:26:31.799 align:start position:0%
# emotional parts of the story and battles
#
#
# 00:26:31.799 --> 00:26:33.430 align:start position:0%
# emotional parts of the story and battles
# that<00:26:31.960><c> spark</c><00:26:32.320><c> excitement</c><00:26:32.760><c> in</c><00:26:32.919><c> you</c>
#
# 00:26:33.430 --> 00:26:33.440 align:start position:0%
# that spark excitement in you
#
#
# 00:26:33.440 --> 00:26:35.870 align:start position:0%
# that spark excitement in you
# entertainment<00:26:34.360><c> education</c><00:26:35.000><c> and</c><00:26:35.240><c> inspiration</c>
#
# 00:26:35.870 --> 00:26:35.880 align:start position:0%
# entertainment education and inspiration
#
#
# 00:26:35.880 --> 00:26:38.350 align:start position:0%
# entertainment education and inspiration
# are<00:26:36.080><c> the</c><00:26:36.240><c> main</c><00:26:36.520><c> goals</c><00:26:37.000><c> of</c><00:26:37.200><c> your</c><00:26:37.520><c> content</c>
#
# 00:26:38.350 --> 00:26:38.360 align:start position:0%
# are the main goals of your content
#
#
# 00:26:38.360 --> 00:26:40.310 align:start position:0%
# are the main goals of your content
# that's<00:26:38.600><c> what</c><00:26:38.720><c> you</c><00:26:38.880><c> are</c><00:26:39.240><c> as</c><00:26:39.360><c> a</c><00:26:39.520><c> content</c><00:26:39.760><c> creator</c>
#
# 00:26:40.310 --> 00:26:40.320 align:start position:0%
# that's what you are as a content creator
#
#
# 00:26:40.320 --> 00:26:42.190 align:start position:0%
# that's what you are as a content creator
# is<00:26:40.520><c> a</c><00:26:40.679><c> mixture</c><00:26:41.000><c> of</c><00:26:41.120><c> an</c><00:26:41.240><c> Entertainer</c><00:26:42.039><c> an</c>
#
# 00:26:42.190 --> 00:26:42.200 align:start position:0%
# is a mixture of an Entertainer an
#
#
# 00:26:42.200 --> 00:26:44.990 align:start position:0%
# is a mixture of an Entertainer an
# educator<00:26:42.679><c> and</c><00:26:42.840><c> an</c><00:26:43.000><c> inspiring</c><00:26:43.840><c> person</c><00:26:44.600><c> so</c>
#
# 00:26:44.990 --> 00:26:45.000 align:start position:0%
# educator and an inspiring person so
#
#
# 00:26:45.000 --> 00:26:46.190 align:start position:0%
# educator and an inspiring person so
# that's<00:26:45.159><c> it</c><00:26:45.320><c> for</c><00:26:45.520><c> this</c><00:26:45.600><c> one</c><00:26:45.799><c> I</c><00:26:45.919><c> hope</c><00:26:46.039><c> you</c>
#
# 00:26:46.190 --> 00:26:46.200 align:start position:0%
# that's it for this one I hope you
#
#
# 00:26:46.200 --> 00:26:47.870 align:start position:0%
# that's it for this one I hope you
# enjoyed<00:26:46.520><c> it</c><00:26:46.679><c> this</c><00:26:46.760><c> one</c><00:26:46.919><c> was</c><00:26:47.080><c> very</c><00:26:47.360><c> practical</c>
#
# 00:26:47.870 --> 00:26:47.880 align:start position:0%
# enjoyed it this one was very practical
#
#
# 00:26:47.880 --> 00:26:50.230 align:start position:0%
# enjoyed it this one was very practical
# but<00:26:48.039><c> you</c><00:26:48.240><c> have</c><00:26:48.399><c> to</c><00:26:48.679><c> actually</c><00:26:49.279><c> practice</c><00:26:50.080><c> the</c>
#
# 00:26:50.230 --> 00:26:50.240 align:start position:0%
# but you have to actually practice the
#
#
# 00:26:50.240 --> 00:26:52.070 align:start position:0%
# but you have to actually practice the
# theory<00:26:50.559><c> so</c><00:26:50.720><c> remember</c><00:26:51.000><c> the</c><00:26:51.159><c> PDF</c><00:26:51.520><c> is</c><00:26:51.720><c> available</c>
#
# 00:26:52.070 --> 00:26:52.080 align:start position:0%
# theory so remember the PDF is available
#
#
# 00:26:52.080 --> 00:26:54.630 align:start position:0%
# theory so remember the PDF is available
# to<00:26:52.279><c> download</c><00:26:53.200><c> in</c><00:26:53.480><c> the</c><00:26:53.679><c> description</c><00:26:54.279><c> also</c><00:26:54.559><c> the</c>
#
# 00:26:54.630 --> 00:26:54.640 align:start position:0%
# to download in the description also the
#
#
# 00:26:54.640 --> 00:26:56.750 align:start position:0%
# to download in the description also the
# art<00:26:54.840><c> of</c><00:26:55.039><c> focus</c><00:26:55.360><c> keepsake</c><00:26:55.919><c> box</c><00:26:56.320><c> or</c><00:26:56.520><c> just</c><00:26:56.640><c> the</c>
#
# 00:26:56.750 --> 00:26:56.760 align:start position:0%
# art of focus keepsake box or just the
#
#
# 00:26:56.760 --> 00:26:59.630 align:start position:0%
# art of focus keepsake box or just the
# art<00:26:56.919><c> of</c><00:26:57.080><c> focus</c><00:26:57.320><c> book</c><00:26:57.679><c> in</c><00:26:57.919><c> general</c><00:26:58.919><c> uh</c><00:26:59.360><c> both</c>
#
# 00:26:59.630 --> 00:26:59.640 align:start position:0%
# art of focus book in general uh both
#
#
# 00:26:59.640 --> 00:27:01.909 align:start position:0%
# art of focus book in general uh both
# available<00:27:00.480><c> Link</c><00:27:00.679><c> in</c><00:27:00.799><c> the</c><00:27:00.960><c> description</c><00:27:01.679><c> if</c><00:27:01.799><c> you</c>
#
# 00:27:01.909 --> 00:27:01.919 align:start position:0%
# available Link in the description if you
#
#
# 00:27:01.919 --> 00:27:03.950 align:start position:0%
# available Link in the description if you
# want<00:27:02.120><c> to</c><00:27:02.320><c> learn</c><00:27:02.720><c> how</c><00:27:02.880><c> to</c><00:27:03.120><c> write</c><00:27:03.440><c> online</c><00:27:03.799><c> and</c>
#
# 00:27:03.950 --> 00:27:03.960 align:start position:0%
# want to learn how to write online and
#
#
# 00:27:03.960 --> 00:27:05.389 align:start position:0%
# want to learn how to write online and
# build<00:27:04.159><c> your</c><00:27:04.360><c> social</c><00:27:04.640><c> media</c><00:27:05.000><c> or</c><00:27:05.120><c> just</c><00:27:05.240><c> a</c>
#
# 00:27:05.389 --> 00:27:05.399 align:start position:0%
# build your social media or just a
#
#
# 00:27:05.399 --> 00:27:07.590 align:start position:0%
# build your social media or just a
# personal<00:27:05.760><c> brand</c><00:27:06.279><c> or</c><00:27:06.520><c> one</c><00:27:06.760><c> person</c><00:27:07.080><c> business</c>
#
# 00:27:07.590 --> 00:27:07.600 align:start position:0%
# personal brand or one person business
#
#
# 00:27:07.600 --> 00:27:08.909 align:start position:0%
# personal brand or one person business
# however<00:27:07.760><c> you</c><00:27:07.840><c> want</c><00:27:07.960><c> to</c><00:27:08.080><c> frame</c><00:27:08.320><c> it</c><00:27:08.559><c> they're</c><00:27:08.760><c> all</c>
#
# 00:27:08.909 --> 00:27:08.919 align:start position:0%
# however you want to frame it they're all
#
#
# 00:27:08.919 --> 00:27:10.909 align:start position:0%
# however you want to frame it they're all
# the<00:27:09.039><c> same</c><00:27:09.279><c> thing</c><00:27:09.799><c> everyone</c><00:27:10.200><c> writes</c><00:27:10.640><c> everyone</c>
#
# 00:27:10.909 --> 00:27:10.919 align:start position:0%
# the same thing everyone writes everyone
#
#
# 00:27:10.919 --> 00:27:12.710 align:start position:0%
# the same thing everyone writes everyone
# needs<00:27:11.120><c> to</c><00:27:11.279><c> communicate</c><00:27:11.760><c> value</c><00:27:12.399><c> everyone</c>
#
# 00:27:12.710 --> 00:27:12.720 align:start position:0%
# needs to communicate value everyone
#
#
# 00:27:12.720 --> 00:27:14.510 align:start position:0%
# needs to communicate value everyone
# wants<00:27:12.960><c> to</c><00:27:13.080><c> do</c><00:27:13.240><c> their</c><00:27:13.360><c> own</c><00:27:13.559><c> thing</c><00:27:14.120><c> so</c><00:27:14.320><c> if</c><00:27:14.440><c> you</c>
#
# 00:27:14.510 --> 00:27:14.520 align:start position:0%
# wants to do their own thing so if you
#
#
# 00:27:14.520 --> 00:27:16.230 align:start position:0%
# wants to do their own thing so if you
# want<00:27:14.640><c> to</c><00:27:14.760><c> do</c><00:27:14.960><c> that</c><00:27:15.159><c> regardless</c><00:27:15.640><c> of</c><00:27:16.000><c> whether</c>
#
# 00:27:16.230 --> 00:27:16.240 align:start position:0%
# want to do that regardless of whether
#
#
# 00:27:16.240 --> 00:27:18.190 align:start position:0%
# want to do that regardless of whether
# it's<00:27:16.480><c> like</c><00:27:16.880><c> labeled</c><00:27:17.360><c> as</c><00:27:17.480><c> a</c><00:27:17.600><c> social</c><00:27:17.880><c> media</c>
#
# 00:27:18.190 --> 00:27:18.200 align:start position:0%
# it's like labeled as a social media
#
#
# 00:27:18.200 --> 00:27:20.230 align:start position:0%
# it's like labeled as a social media
# influencer<00:27:18.720><c> or</c><00:27:18.880><c> not</c><00:27:19.240><c> just</c><00:27:19.440><c> write</c><00:27:19.679><c> online</c><00:27:20.159><c> if</c>
#
# 00:27:20.230 --> 00:27:20.240 align:start position:0%
# influencer or not just write online if
#
#
# 00:27:20.240 --> 00:27:21.750 align:start position:0%
# influencer or not just write online if
# you<00:27:20.320><c> want</c><00:27:20.440><c> to</c><00:27:20.559><c> do</c><00:27:20.720><c> that</c><00:27:20.880><c> to</c><00:27:21.080><c> our</c><00:27:21.240><c> writer</c><00:27:21.679><c> the</c>
#
# 00:27:21.750 --> 00:27:21.760 align:start position:0%
# you want to do that to our writer the
#
#
# 00:27:21.760 --> 00:27:23.430 align:start position:0%
# you want to do that to our writer the
# course<00:27:22.000><c> Link</c><00:27:22.200><c> in</c><00:27:22.320><c> the</c><00:27:22.440><c> description</c><00:27:23.240><c> other</c>
#
# 00:27:23.430 --> 00:27:23.440 align:start position:0%
# course Link in the description other
#
#
# 00:27:23.440 --> 00:27:25.750 align:start position:0%
# course Link in the description other
# cool<00:27:23.720><c> stuff</c><00:27:24.480><c> check</c><00:27:24.679><c> all</c><00:27:24.840><c> it</c><00:27:24.960><c> out</c><00:27:25.360><c> thanks</c><00:27:25.559><c> for</c>
#
# 00:27:25.750 --> 00:27:25.760 align:start position:0%
# cool stuff check all it out thanks for
#
#
# 00:27:25.760 --> 00:27:28.679 align:start position:0%
# cool stuff check all it out thanks for
# watching<00:27:26.360><c> peace</c>

# %% [markdown]
# ## Functions

# %%
auto_captions = Captions.from_file(SAMPLE_AUTO_SUBTITLE_FILE)

auto_captions.df.head()
# Out:
# shape: (5, 3)
# ┌───────┬───────┬───────────────────────────────────┐
# │ start ┆ end   ┆ text                              │
# │ ---   ┆ ---   ┆ ---                               │
# │ f64   ┆ f64   ┆ str                               │
# ╞═══════╪═══════╪═══════════════════════════════════╡
# │ 0.12  ┆ 4.749 ┆ the greatest skill of the 21st c… │
# │ 2.399 ┆ 6.909 ┆ is not email marketing it is not… │
# │ 4.759 ┆ 8.549 ┆ design it is not web design it i… │
# │ 6.919 ┆ 11.07 ┆ artificial intelligence it is no… │
# │ 8.559 ┆ 14.43 ┆ personal branding it is not vide… │
# └───────┴───────┴───────────────────────────────────┘

# %%
captions = Captions.from_file(SAMPLE_EN_US_SUBTITLE_FILE)

captions.df.head()
# Out:
# shape: (5, 3)
# ┌───────┬───────┬───────────────────────────────────┐
# │ start ┆ end   ┆ text                              │
# │ ---   ┆ ---   ┆ ---                               │
# │ f64   ┆ f64   ┆ str                               │
# ╞═══════╪═══════╪═══════════════════════════════════╡
# │ 0.041 ┆ 3.837 ┆ The greatest skill of the 21st c… │
# │ 3.878 ┆ 5.255 ┆ It is not graphic design.         │
# │ 5.255 ┆ 6.423 ┆ It is not web design.             │
# │ 6.423 ┆ 8.133 ┆ It is not artificial intelligenc… │
# │ 8.133 ┆ 9.426 ┆ It is not personal branding.      │
# └───────┴───────┴───────────────────────────────────┘

# %%
# Read json
with open(SAMPLE_VIDEO_INFO_FILE) as f:
    video_info = json.load(f)

# %%
video_info_df = pl.DataFrame([video_info])

video_info_df.columns
# Out:
# dict_keys(['id', 'title', 'formats', 'thumbnails', 'thumbnail', 'description', 'channel_id', 'channel_url', 'duration', 'view_count', 'age_limit', 'webpage_url', 'categories', 'tags', 'playable_in_embed', 'live_status', '_format_sort_fields', 'automatic_captions', 'subtitles', 'comment_count', 'chapters', 'heatmap', 'channel', 'channel_follower_count', 'uploader', 'uploader_id', 'uploader_url', 'upload_date', 'availability', 'webpage_url_basename', 'webpage_url_domain', 'extractor', 'extractor_key', 'playlist_count', 'playlist', 'playlist_id', 'playlist_title', 'playlist_uploader', 'playlist_uploader_id', 'n_entries', 'playlist_index', 'display_id', 'fulltitle', 'duration_string', 'is_live', 'was_live', 'epoch', 'format', 'format_id', 'ext', 'protocol', 'language', 'format_note', 'filesize_approx', 'tbr', 'width', 'height', 'resolution', 'fps', 'dynamic_range', 'vcodec', 'vbr', 'aspect_ratio', 'acodec', 'abr', 'asr', 'audio_channels', '_type', '_version'])

# %%
relevant_columns = [
    "title",
    "formats",
    "description",
    "duration",
    "categories",
    "tags",
    "playable_in_embed",
    "automatic_captions",
    "subtitles",
    "chapters",
    "heatmap",
    "upload_date",
    "availability",
    "playlist_title",
    "playlist_index",
    "fulltitle",
    "language",
    "filesize_approx",
]

# %%
# Polars seems to have no way to constrain overall cell width for all data types.
# https://stackoverflow.com/q/75786523/7454638
# with pl.Config(tbl_cols=len(relevant_columns), fmt_str_lengths=20) as cfg:
#     display(video_info_df.select(relevant_columns))

with pd.option_context("display.max_columns", None):
    display(video_info_df.to_pandas()[relevant_columns])
# Out:
#                                                title  \
# 0  The Greatest Skill Of The 21st Century (The To...
#
#                                              formats  \
# 0  [{'format_id': 'sb2', 'format_note': 'storyboa...
#
#                                          description  duration   categories  \
# 0  Download this PDF and emulate it while you are...      1647  [Education]
#
#                                                 tags  playable_in_embed  \
# 0  [self improvement, mindset, personal developme...               True
#
#                                   automatic_captions  \
# 0  {'en-US': [{'url': 'https://manifest.googlevid...
#
#                                            subtitles  \
# 0  {'en-US': [{'ext': 'json3', 'url': 'https://ww...
#
#                                             chapters  \
# 0  [{'start_time': 0.0, 'title': 'What Is The Gre...
#
#                                              heatmap upload_date availability  \
# 0  [{'start_time': 0.0, 'end_time': 16.47, 'value...    20231105       public
#
#      playlist_title  playlist_index  \
# 0  Dan Koe - Videos               4
#
#                                            fulltitle language  filesize_approx
# 0  The Greatest Skill Of The 21st Century (The To...       en         27050826

# %%
(
    captions_df.with_columns(
        tpl.time_based_replace(
            video_info["chapters"], info_value_column="title", taget_column="chapters"
        )
    ).with_columns(
        tpl.time_based_replace(
            video_info["heatmap"],
            info_value_column="value",
            taget_column="heatmap",
            default_value=0,
        )
    )
)
# Out:
# shape: (755, 5)
# ┌──────────┬──────────┬────────────────────────────────┬────────────────────────────────┬──────────┐
# │ start    ┆ end      ┆ text                           ┆ chapters                       ┆ heatmap  │
# │ ---      ┆ ---      ┆ ---                            ┆ ---                            ┆ ---      │
# │ f64      ┆ f64      ┆ str                            ┆ str                            ┆ f64      │
# ╞══════════╪══════════╪════════════════════════════════╪════════════════════════════════╪══════════╡
# │ 0.041    ┆ 3.837    ┆ The greatest skill of the 21st ┆ What Is The Greatest Skill Of  ┆ 0.01439  │
# │          ┆          ┆ c…                             ┆ Th…                            ┆          │
# │ 3.878    ┆ 5.255    ┆ It is not graphic design.      ┆ What Is The Greatest Skill Of  ┆ 0.01439  │
# │          ┆          ┆                                ┆ Th…                            ┆          │
# │ 5.255    ┆ 6.423    ┆ It is not web design.          ┆ What Is The Greatest Skill Of  ┆ 0.01439  │
# │          ┆          ┆                                ┆ Th…                            ┆          │
# │ 6.423    ┆ 8.133    ┆ It is not artificial           ┆ What Is The Greatest Skill Of  ┆ 0.01439  │
# │          ┆          ┆ intelligenc…                   ┆ Th…                            ┆          │
# │ …        ┆ …        ┆ …                              ┆ …                              ┆ …        │
# │ 1636.885 ┆ 1640.013 ┆ labeled as a social media      ┆ What Creates Engagement?       ┆ 0.000479 │
# │          ┆          ┆ influe…                        ┆                                ┆          │
# │ 1640.138 ┆ 1641.64  ┆ If you want to do that to a    ┆ What Creates Engagement?       ┆ 0.000479 │
# │          ┆          ┆ writ…                          ┆                                ┆          │
# │ 1641.64  ┆ 1644.434 ┆ the course link in the         ┆ What Creates Engagement?       ┆ 0.000479 │
# │          ┆          ┆ descripti…                     ┆                                ┆          │
# │ 1644.434 ┆ 1646.561 ┆ Check it out. Thanks for       ┆ What Creates Engagement?       ┆ 0.000479 │
# │          ┆          ┆ watchin…                       ┆                                ┆          │
# └──────────┴──────────┴────────────────────────────────┴────────────────────────────────┴──────────┘
